# %% [markdown]
# ## Лабораторна робота №2

# %% [markdown]
# ### Тема. Налагоджування та робота в середовищі Anaconda+Quarto"

# %% [markdown]
# ### Мета: швидкий старт для роботи в середовищі Anaconda із застосуванням Jupyter Notebook, або Jupyter Notebook засобами мови програмування Python та видавничої системи Quarto.
#
# ### Виконав: Роменський Г.О.

# %% [markdown]
# Після того, як був завантажений miniconda, виконує такі завдання з налаштування:

# %% [markdown]
# *Завдання 1: Створюємо два таких середовища:*
#
# * `py311` -- середовище з Python 3.11
# * `py312`-- середовище з Python 3.12

# %% [markdown]
# ![image1](Images\1.png)

# %% [markdown]
# ![image2](Images\2.png)

# %% [markdown]
# Ці середовища ми створювали під різні версії Python:
# * conda create -n py311 python=3.11
# * conda create -n py312 python=3.12

# %% [markdown]
# ![image3](Images\3.png)

# %% [markdown]
# *Завдання 2: створення середовищ`ds-base-2026.1` та `py-dev-base`*
#
# conda create -n ds-base-2026.1 python=3.11 numpy scipy pandas matplotlib seaborn scikit-learn jupyterlab ipykernel

# %% [markdown]
# ![image4](Images\4.png)

# %% [markdown]
# Далі було зроблене копіювання цього середовища:
#
# conda create -n asd --clone ds-base-2026.1

# %% [markdown]
# ![image5](Images\5.png)

# %% [markdown]
# *Завдання 3: Реєстрація kernel для середовища `asd`*
#
# python -m ipykernel install --user --name asd --display-name "Python (asd)"

# %% [markdown]
# ![image6](Images\6.png)

# %% [markdown]
# *Завдання 4:Positron: вибір kernel і перевірка `sys.executable`*

# %% [markdown]
# ![image7](Images\7.png)

# %% [markdown]
# ![image8](Images\8.png)

# %% [markdown]
# ## Висновок: під час виконнання цієї лабораторної роботи я навчився працювати в середовищі Anaconda із застосуванням Jupyter Notebook, або Jupyter Notebook засобами мови програмування Python та видавничої системи Quarto.

# %% [markdown]
# *Контрольні питання:*
# 1) Часто призводить до конфліктів бібліотек і проблем з оновленнями. Також важко ізолювати проєкти між собою.
# 2) Кожен проєкт мав свої версії бібліотек і не ламав інші. Це забезпечує стабільність і відтворюваність.
# 3) Базове середовище — це основне Conda-середовище, яке краще не чіпати. Проєктне створюється окремо і використовується тільки для конкретного проєкту.
# 4) Файл, який описує всі залежності середовища (Python і бібліотеки). Його використовують для відтворення однакового середовища на іншому комп’ютері.
# 5) Через import sys; print(sys.executable) у JupyterLab. Це покаже шлях до активного Python.
